# %% [markdown]
# # Blub & Fuel: Five Engines, One Domain
#
# Open any chapter to read it as a notebook. Code blocks appear as cells you can
# edit and copy, but no kernel is wired up — this is a read/study experience, not
# an execution environment. Mermaid diagrams are pre-rendered to inline SVG.
#
# ## Chapters
#
# 1. [Blub & Fuel](index.ipynb)
# 1. [Setup](setup.ipynb)
# 1. [The Blub Paradox](part1/01-blub-paradox.ipynb)
# 1. [Tour: the normal C# fuel engine](part1/02-normal-csharp-tour.ipynb)
# 1. [Seven footguns](part1/03-seven-footguns.ipynb)
# 1. [Idiomatic C#: same language, modern features on](part1/04-idiomatic-csharp.ipynb)
# 1. [F#: leaving C# behind](part1/05-fsharp-native.ipynb)
# 1. [F# interop: where the domain meets C#](part1/06-fsharp-interop.ipynb)
# 1. [A Haskell primer for C# developers](part1/07-haskell-primer.ipynb)
# 1. [Haskell: making the bug unrepresentable](part1/08-haskell-safety.ipynb)
# 1. [Rust: a different goal, the same place](part1/09-rust-lands.ipynb)
# 1. [The punch: what each rung made impossible](part1/10-the-punch.ipynb)
# 1. [The boundary returns](part1b/11-boundary-returns.ipynb)
# 1. [Four engines at the boundary](part1b/12-boundary-side-by-side.ipynb)
# 1. [The final takeaway](part1b/13-final-takeaway.ipynb)
# 1. [Modelling the row decision](part2/r1-decision.ipynb)
# 1. [Validation and warnings](part2/r2-validation.ipynb)
# 1. [Duplicate / recovery policy](part2/r3-recovery.ipynb)
# 1. [The boundary](part2/r4-boundary.ipynb)
# 1. [Exhaustiveness](part2/r5-exhaustiveness.ipynb)
# 1. [Mutability and identity](part2/r6-mutability.ipynb)
# 1. [Null and absence](part2/r7-null.ipynb)
# 1. [references](references.ipynb)
